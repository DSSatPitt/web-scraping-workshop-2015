# %% [markdown]
# # Scraping the iConference 2015 Program

# %% [markdown]
# The purpose of this exercise is to demonstrate some basic web scraping practices using the python programming language.

# %%
# import 3rd party libraries for fetching and parsing HTML documents 
from lxml import html
import requests

# %% [markdown]
# The website we are going to scrape is the [2015 iConference program](https://www.conftool.com/iConference2015/sessions.php). To make our jobs easier, we are going to scape the [print and list view](https://www.conftool.com/iConference2015/index.php?page=browseSessions&print=head&mode=list) of the page.
#
# - URL: https://www.conftool.com/iConference2015/index.php?page=browseSessions&print=head&mode=list

# %%
# put the base URL for the web scrape into a variable called "urly"
urly = "https://www.conftool.com/iConference2015/index.php?page=browseSessions&print=head&mode=list"

# %%
# fetch the web page containing the program for the iConference
response = requests.get(urly) # put the response into a variable called "response"

# %%
# parse the HTML document stored in the response variable 
# using the lxml parser imported above
iconf_program = html.document_fromstring(response.content)

# %% [markdown]
# Ok, now we have *fetched* and *parsed* the HTML document we can *extract* data.
#
# What data do we want to extract? How about a list of all the events!
#
# Lets do an *inspect element* on the [program page](https://www.conftool.com/iConference2015/index.php?page=browseSessions&print=head&mode=list) and see what the HTML structure looks like.
#
# ![Finding individual events in the iConference program page](iconf-events.png)
#
# If you look carefully you can see the tag `<tr class="whitebg">` indentifies each row in the table of events. We can use that to select only the information we want from the rest of the page.

# %%
# crafting an XPATH selector that extracts the <b> tags 
# that are children of a <tr> tag with a CSS class equal to 'whitebg'
# this basically finds the event titles from the page
selector = "//tr[@class='whitebg']//b"

# pull out all the event titles from the HTML document
event_list = iconf_program.xpath(selector)

# loop over the extracted information and print the event title
for event in event_list:
    print(event.text_content())
# Out:
# Workshop 8: Values as Generative Forces in Design (Session 1)
# Workshop 9: Visualization Pedagogy in iSchools (Session 1)
# Undergraduate Education in iSchools (Session 1)
# Workshop 4: Digital Youth Research Network: Defining The Field, Building Connections, and Exploring Collaborations (Session 1)
# Workshop 5: ICT for Sustainability â Current and future research directions (Session 1)
# Workshop 2: Exploring Gender, Race, and Sexuality with Social Media Data (Session 1)
# Workshop 6: Sociotechnical Approaches to Fieldwork and Trace Data Integration (Session 1)
# Workshop 7: Authoring, Designing, and Delivering Ebooks: A Research and Practice Agenda (Session 1)
# Workshop 1: Trace Ethnography Workshop (Session 1)
# Break (Tuesday AM)
# Workshop 8: Values as Generative Forces in Design (Session 2)
# Workshop 9: Visualization Pedagogy in iSchools (Session 2)
# Undergraduate Education in iSchools (Session 2)
# Workshop 4: Digital Youth Research Network: Defining The Field, Building Connections, and Exploring Collaborations (Session 2)
# Workshop 5: ICT for Sustainability â Current and future research directions (Session 2)
# Workshop 2: Exploring Gender, Race, and Sexuality with Social Media Data (Session 2)
# Workshop 6: Sociotechnical Approaches to Fieldwork and Trace Data Integration (Session 2)
# Workshop 7: Authoring, Designing, and Delivering Ebooks: A Research and Practice Agenda (Session 2)
# Workshop 1: Trace Ethnography Workshop (Session 2)
# Lunch (Tuesday)
# Workshop 11: Evaluating Cultural Heritage Information Systems (Session 1)
# Workshop 12: A Collaborative Approach to Improving Information Ethics Education (Session 1)
# iSchools Meeting (Session 1)
# Undergraduate Education in iSchools (Session 3)
# Workshop 4: Digital Youth Research Network: Defining The Field, Building Connections, and Exploring Collaborations (Session 3)
# Workshop 5: ICT for Sustainability â Current and future research directions (Session 3)
# Workshop 2: Exploring Gender, Race, and Sexuality with Social Media Data (Session 3)
# Workshop 6: Sociotechnical Approaches to Fieldwork and Trace Data Integration (Session 3)
# Workshop 10: On the Role of Engagement in Information Seeking Contexts: From Research to Implementation (Session 1)
# Workshop 1: Trace Ethnography Workshop (Session 3)
# Break (Tuesday PM)
# Workshop 11: Evaluating Cultural Heritage Information Systems (Session 2)
# Workshop 12: A Collaborative Approach to Improving Information Ethics Education (Session 2)
# iSchools Meeting (Session 2)
# Undergraduate Education in iSchools (Session 4)
# Workshop 4: Digital Youth Research Network: Defining The Field, Building Connections, and Exploring Collaborations (Session 4)
# Workshop 5: ICT for Sustainability â Current and future research directions (Session 4)
# Workshop 2: Exploring Gender, Race, and Sexuality with Social Media Data (Session 4)
# Workshop 6: Sociotechnical Approaches to Fieldwork and Trace Data Integration (Session 4)
# Workshop 10: On the Role of Engagement in Information Seeking Contexts: From Research to Implementation (Session 2)
# Workshop 1: Trace Ethnography Workshop (Session 4)
# Welcome Reception
# Scott Page: Two Models of Collective Intelligence
# Gary Olson
# Break (Wednesday AM)
# Completed Papers 1: Exploring Scientific Work
# Kalpana Shankar
# Completed Papers 2: Participating in E-Government and Political Action
# Gloria Mark
# Completed Papers 3: Extracting, Comparing and Creating Book and Journal Data
# Dania Bilal
# Preliminary Papers 1: Sound, Language and Culture
# Nicholas Belkin
# SIE 1: Learning Analytics (Session 1)
# SIE 2: Response to NSA (Session 1)
# Lunch (Wednesday)
# Demo: Microsoft Azure Machine Learning Demo
# Alex D. Wade
# Completed Papers 4: Developing Online Interaction
# Warren Allen
# Completed Papers 5: Addressing Law, Policy and Ethics
# Andrew Clement
# Preliminary Papers 2: Big Data, Big Infrastructure, Big Knowledge
# Cecilia R. Aragon
# Preliminary Papers 3: Visualization and Interaction
# Chirag Shah
# SIE 3: Beyond the Backchannel (Session 1)
# SIE 4: iCollaboration
# iConsortium Meeting (Session 1)
# Break (Wednesday PM)
# Completed Papers 6: Thinking About Online Education
# Yong Ming Kow
# Completed Papers 7: Advancing Technologies
# Geoffrey Bowker
# Preliminary Papers 4: Government Related Infrastructure
# Gillian Hayes
# Preliminary Papers 5: Thematic and Meta Analysis
# Michael Khoo
# SIE 5: Core Competencies
# Social Media Expo
# iConsortium Meeting (Session 2)
# Poster Session 1
# Busses to Newport Dunes
# Dinner at Newport Dunes
# Carole Goble: Results Vary: The Pragmatics of Reproducibility and Research Object Frameworks
# Thomas Finholt
# Break (Thursday AM)
# Completed Papers 8: Designing Crowdsourcing Applications
# Patrick C. Shih
# Completed Papers 9: Living On and Through Social Media
# Ricardo Gomez
# Completed Papers 10: Managing Knowledge and Information
# Stephen Voida
# Preliminary Papers 6: Improving the Academy
# Stephanie D. Teasley
# SIE 6: Draw My Life
# NSF: NSF Informational Session
# Kevin Crowston
# iCaucus Business Meeting (Session 1)
# Lunch (Thursday)
# Completed Papers 11: Engaging Social Media and the Crowd
# Douglas W. Oard
# Completed Papers 12: Using Mobile Health Applications
# Yunan Chen
# Preliminary Papers 7: Voice of the Underrepresented
# Wayne Lutters
# Preliminary Papers 8: Knowledge Management in Academia
# Susan Gasson
# SIE 8: Psychophysiological Methods
# SIE 7: Pipelines and Pathways (Diversity)
# iCaucus Business Meeting (Session 2)
# Break (Thursday PM)
# Completed Papers 13: Understanding Demographic Groups
# Andrea Tapia
# Completed Papers 14: Designing Services and Products
# Elke Greifeneder
# Preliminary Papers 9: The Other Side of Social Media
# Jonathan Foster
# Preliminary Papers 10: Academic Infrastructures and Knowledge Management
# Steve Sawyer
# SIE 3: Beyond the Backchannel (Session 2)
# iCaucus Business Meeting (Session 3)
# Poster Session 2 + Reception
# Completed Papers 15: Examining Information Behavior in Context
# lynette kvasny
# Completed Papers 16: Organizations: Learning, Growing, Changing
# Catherine Blake
# Completed Papers 17: Envisioning Public and Digital Libraries
# Howard Rosenbaum
# SIE 1: Learning Analytics (Session 2)
# SIE 2: Response to NSA (Session 2)
# Colloquium 3: Doctoral Colloquium
# Break (Friday AM)
# Christine L. Borgman: Creating, Collaborating, and Celebrating the Diversity of Research Data
# Gary Olson
# Farewell Ice Cream Social, Lunch On Your Own (Friday)
# Christine L. Borgman: Book signing
# Early Career Colloquium (Session 1)
# Colloquium 4: Doctoral Colloquium
# Early Career Colloquium (Session 2)
# Colloquium 5: Doctoral Colloquium

# %% [markdown]
# **Awesome!**
#
# But now everything is mooshed together into a undifferentiated pile. Lets see if we can separate the different events.
#
# ![See how background color is used to distinguish events](distinguish-events.png)
#
# Different events have different background colors. Those colors are defined using the CSS `background` attribute. We can use this information to specifically extract each of the different event types.

# %%
# list the completed papers by selecting rows with the background color e0ffff
selector = "//td[@style='background:#e0ffff']/a"
for row in iconf_program.xpath(selector):
    print(row.text_content())
# Out:
# Completed Papers 1: Exploring Scientific Work
# Completed Papers 2: Participating in E-Government and Political Action
# Completed Papers 3: Extracting, Comparing and Creating Book and Journal Data
# Completed Papers 4: Developing Online Interaction
# Completed Papers 5: Addressing Law, Policy and Ethics
# Completed Papers 6: Thinking About Online Education
# Completed Papers 7: Advancing Technologies
# Completed Papers 8: Designing Crowdsourcing Applications
# Completed Papers 9: Living On and Through Social Media
# Completed Papers 10: Managing Knowledge and Information
# Completed Papers 11: Engaging Social Media and the Crowd
# Completed Papers 12: Using Mobile Health Applications
# Completed Papers 13: Understanding Demographic Groups
# Completed Papers 14: Designing Services and Products
# Completed Papers 15: Examining Information Behavior in Context
# Completed Papers 16: Organizations: Learning, Growing, Changing
# Completed Papers 17: Envisioning Public and Digital Libraries

# %%
# list the workshops by selecting rows with the background color f0f8ff

selector = "//td[@style='background:#f0f8ff']/a"
for row in iconf_program.xpath(selector):
    print(row.text_content())
# Out:
# Workshop 8: Values as Generative Forces in Design (Session 1)
# Workshop 9: Visualization Pedagogy in iSchools (Session 1)
# Workshop 4: Digital Youth Research Network: Defining The Field, Building Connections, and Exploring Collaborations (Session 1)
# Workshop 5: ICT for Sustainability â Current and future research directions (Session 1)
# Workshop 2: Exploring Gender, Race, and Sexuality with Social Media Data (Session 1)
# Workshop 6: Sociotechnical Approaches to Fieldwork and Trace Data Integration (Session 1)
# Workshop 7: Authoring, Designing, and Delivering Ebooks: A Research and Practice Agenda (Session 1)
# Workshop 1: Trace Ethnography Workshop (Session 1)
# Workshop 8: Values as Generative Forces in Design (Session 2)
# Workshop 9: Visualization Pedagogy in iSchools (Session 2)
# Workshop 4: Digital Youth Research Network: Defining The Field, Building Connections, and Exploring Collaborations (Session 2)
# Workshop 5: ICT for Sustainability â Current and future research directions (Session 2)
# Workshop 2: Exploring Gender, Race, and Sexuality with Social Media Data (Session 2)
# Workshop 6: Sociotechnical Approaches to Fieldwork and Trace Data Integration (Session 2)
# Workshop 7: Authoring, Designing, and Delivering Ebooks: A Research and Practice Agenda (Session 2)
# Workshop 1: Trace Ethnography Workshop (Session 2)
# Workshop 11: Evaluating Cultural Heritage Information Systems (Session 1)
# Workshop 12: A Collaborative Approach to Improving Information Ethics Education (Session 1)
# Workshop 4: Digital Youth Research Network: Defining The Field, Building Connections, and Exploring Collaborations (Session 3)
# Workshop 5: ICT for Sustainability â Current and future research directions (Session 3)
# Workshop 2: Exploring Gender, Race, and Sexuality with Social Media Data (Session 3)
# Workshop 6: Sociotechnical Approaches to Fieldwork and Trace Data Integration (Session 3)
# Workshop 10: On the Role of Engagement in Information Seeking Contexts: From Research to Implementation (Session 1)
# Workshop 1: Trace Ethnography Workshop (Session 3)
# Workshop 11: Evaluating Cultural Heritage Information Systems (Session 2)
# Workshop 12: A Collaborative Approach to Improving Information Ethics Education (Session 2)
# Workshop 4: Digital Youth Research Network: Defining The Field, Building Connections, and Exploring Collaborations (Session 4)
# Workshop 5: ICT for Sustainability â Current and future research directions (Session 4)
# Workshop 2: Exploring Gender, Race, and Sexuality with Social Media Data (Session 4)
# Workshop 6: Sociotechnical Approaches to Fieldwork and Trace Data Integration (Session 4)
# Workshop 10: On the Role of Engagement in Information Seeking Contexts: From Research to Implementation (Session 2)
# Workshop 1: Trace Ethnography Workshop (Session 4)

# %%
# list the keynotes by selecting rows with the background color fff8cd

selector = "//td[@style='background:#fff8cd']/a"
for row in iconf_program.xpath(selector):
    print(row.text_content())
# Out:
# Scott Page: Two Models of Collective Intelligence
# Carole Goble: Results Vary: The Pragmatics of Reproducibility and Research Object Frameworks
# Christine L. Borgman: Creating, Collaborating, and Celebrating the Diversity of Research Data

# %%
# list the preliminary papers by selecting rows with the background color fff5ee

selector = "//td[@style='background:#fff5ee']/a"
for row in iconf_program.xpath(selector):
    print(row.text_content())
# Out:
# Preliminary Papers 1: Sound, Language and Culture
# Preliminary Papers 2: Big Data, Big Infrastructure, Big Knowledge
# Preliminary Papers 3: Visualization and Interaction
# Preliminary Papers 4: Government Related Infrastructure
# Preliminary Papers 5: Thematic and Meta Analysis
# Preliminary Papers 6: Improving the Academy
# Preliminary Papers 7: Voice of the Underrepresented
# Preliminary Papers 8: Knowledge Management in Academia
# Preliminary Papers 9: The Other Side of Social Media
# Preliminary Papers 10: Academic Infrastructures and Knowledge Management

# %% [markdown]
# ### Extracting Author names

# %% [markdown]
# Ok, now let's do something more interesting and extract the names of all the authors who wrote completed papers.
#
# Bu the information is not on this page! We need to follow links to the completed papers sessions. This means we need to make a very basic web crawler!
#
# ![Inspecting a completed papers session page](paper-session.png)

# %%
# extract the links to just the paper sessions
selector = "//td[@style='background:#e0ffff']/a/@href"

# loop over all of the links
for url in iconf_program.xpath(selector):
    # fetch and parse each of the paper session pages
    paper_session = html.fromstring(requests.get(url).content)
    
    # extract the author names from the session pages
    author_selector = "//p[@class='paper_author']"
    author_elements = paper_session.xpath(author_selector)
    
    # loop over all the authors & print out the names
    for author in author_elements:
        print(author.text_content())
# Out:
#  Steve Slota1, Geoffrey C. Bowker2
#  Drew Paine, Erin Sy, Ron Piell, Charlotte P. Lee
#  Peter T. Darch, Ashley E. Sands
#  Agnes Mainka, Sarah Hartmann, Christine Meschede, Wolfgang G. Stock
#  Catherine Dumas, Daniel LaManna, Teresa M. Harrison, S.S. Ravi, Loni Hagen, Christopher Kotfila, Feng Chen
#  Norman Meuschke1,2, Bela Gipp1, Mario Lipinsk1
#  Henry A. Gabb, Ana Lucic, Catherine Blake
#  Toine Bogers1, Vivien Petras2
#  Adam Worrall
#  Colin Doty
#  Saleem Alhabash1,2, Brandon Allen Brooks2, Mengtian Jiang1, Nora J Rifon1, LaRose Robert2, Cotten Shelia2
#  Alissa Lorraine Centivany
#  Alon Peled1, Karine Nahon2,3
#  Katie Shilton
#  Michael Marcinkowski, Frederico Fonseca
#  Rob Grace, Frederico Fonseca
#  Tuan Cong Dang, Jonathan Foster
#  Williams Ezinwa Nwagwu
#  Thomas Ludwig1, Oliver Stickel1, Alexander Boden2, Volkmar Pipek1, Volker Wulf1
#  Hamid R. Ekbia1, Bonnie Nardi2, Selma Sabanovic1
#  Donna Vakharia1, Matthew Lease2
#  Peter Organisciak, Michael Twidale
#  Elliot Tan1, Huichuan Xia2, Cheng Ji2, Ritu Virendra Joshi2, Yun Huang2
#  Martin Shelton, Katherine Lo, Bonnie Nardi
#  Munmun De Choudhury1, Michael Massimi2
#  Jinyoung Kim, Myeong Lee, Chiyoung Oh
#  Karin Dessne
#  Allyson Carlyle
#  Susan Gasson
#  Judit Bar-Ilan, Jenny Bronstein, Noa Aharony
#  James Cheng1, Monisha Manoharan2, Yan Zhang1, Matthew Lease1
#  Donghee Yvette Wohn
#  Patrick C. Shih, Kyungsik Han, Erika Shehan Poole, Mary Beth Rosson, John M. Carroll
#  Elizabeth Eikey, Erika Poole, Madhu Reddy
#  Shameem Ahmed1, Moushumi Sharmin2
#  Vanessa Kitzie
#  R. J. Shillair, R.V. Rikard, S.R. Cotten, H.Y. Tsai
#  Kuo-Ting Huang, Shelia Cotten, Christopher Ball
#  Anders Hjalmarsson1,2, Eva Gustafsson1, Stefan Cronholm1
#  Daniel Carter
#  Patrick Carrington2, Shannon Hosmer2, Tom Yeh1, Amy Hurst2, Shaun K. Kane1
#  Roberto I Gonzalez-IbaÃ±ez1, Chirag Shah2
#  SoHyun Park, Hyunchul Lim, Heekyung Choi
#  Chirag Shah, Jennifer Sonne
#  You Zheng, Jason Dedrick
#  Jess Kropczynski
#  Cheryl Annette Thompson1, Matthew S. Mayernik2, Carole L. Palmer3, Suzie Allard4, Carol Tenopir4
#  Michael Majewski Widdersheim, Masanori Koizumi
#  Siyuan Guo, Trevor Edelblute, Bin Dai, Miao Chen, Xiaozhong Liu

# %%
# lets do it again, but concatinate them all together into a variable
author_string = ""

# fetch the links to paper sessions
selector = "//td[@style='background:#e0ffff']/a/@href"
for url in iconf_program.xpath(selector):
    paper_session = html.fromstring(requests.get(url).content)
    author_selector = "//p[@class='paper_author']"
    author_elements = paper_session.xpath(author_selector)
    for author in author_elements:
        author_string += author.text_content() + ","
        
author_string # list of all the authors separated by commas
# Out:
# ' Steve Slota1, Geoffrey C. Bowker2, Drew Paine, Erin Sy, Ron Piell, Charlotte P. Lee, Peter T. Darch, Ashley E. Sands, Agnes Mainka, Sarah Hartmann, Christine Meschede, Wolfgang G. Stock, Catherine Dumas, Daniel LaManna, Teresa M. Harrison, S.S. Ravi, Loni Hagen, Christopher Kotfila, Feng Chen, Norman Meuschke1,2, Bela Gipp1, Mario Lipinsk1, Henry A. Gabb, Ana Lucic, Catherine Blake, Toine Bogers1, Vivien Petras2, Adam Worrall, Colin Doty, Saleem Alhabash1,2, Brandon Allen Brooks2, Mengtian Jiang1, Nora J Rifon1, LaRose Robert2, Cotten Shelia2, Alissa Lorraine Centivany, Alon Peled1, Karine Nahon2,3, Katie Shilton, Michael Marcinkowski, Frederico Fonseca, Rob Grace, Frederico Fonseca, Tuan Cong Dang, Jonathan Foster, Williams Ezinwa Nwagwu, Thomas Ludwig1, Oliver Stickel1, Alexander Boden2, Volkmar Pipek1, Volker Wulf1, Hamid R. Ekbia1, Bonnie Nardi2, Selma Sabanovic1, Donna Vakharia1, Matthew Lease2, Peter Organisciak, Michael Twidale, Elliot Tan1, Huichuan Xia2, Cheng Ji2, Ritu Virendra Joshi2, Yun Huang2, Martin Shelton, Katherine Lo, Bonnie Nardi, Munmun De Choudhury1, Michael Massimi2, Jinyoung Kim, Myeong Lee, Chiyoung Oh, Karin Dessne, Allyson Carlyle, Susan Gasson, Judit Bar-Ilan, Jenny Bronstein, Noa Aharony, James Cheng1, Monisha Manoharan2, Yan Zhang1, Matthew Lease1, Donghee Yvette Wohn, Patrick C. Shih, Kyungsik Han, Erika Shehan Poole, Mary Beth Rosson, John M. Carroll, Elizabeth Eikey, Erika Poole, Madhu Reddy, Shameem Ahmed1, Moushumi Sharmin2, Vanessa Kitzie, R. J. Shillair, R.V. Rikard, S.R. Cotten, H.Y. Tsai, Kuo-Ting Huang, Shelia Cotten, Christopher Ball, Anders Hjalmarsson1,2, Eva Gustafsson1, Stefan Cronholm1, Daniel Carter, Patrick Carrington2, Shannon Hosmer2, Tom Yeh1, Amy Hurst2, Shaun K. Kane1, Roberto I Gonzalez-IbaÃ±ez1, Chirag Shah2, SoHyun Park, Hyunchul Lim, Heekyung Choi, Chirag Shah, Jennifer Sonne, You Zheng, Jason Dedrick, Jess Kropczynski, Cheryl Annette Thompson1, Matthew S. Mayernik2, Carole L. Palmer3, Suzie Allard4, Carol Tenopir4, Michael Majewski Widdersheim, Masanori Koizumi, Siyuan Guo, Trevor Edelblute, Bin Dai, Miao Chen, Xiaozhong Liu,'

# %% [markdown]
# # DATA CLEANING!

# %%
author_string.split(',')
# Out:
# [' Steve Slota1',
#  ' Geoffrey C. Bowker2',
#  ' Drew Paine',
#  ' Erin Sy',
#  ' Ron Piell',
#  ' Charlotte P. Lee',
#  ' Peter T. Darch',
#  ' Ashley E. Sands',
#  ' Agnes Mainka',
#  ' Sarah Hartmann',
#  ' Christine Meschede',
#  ' Wolfgang G. Stock',
#  ' Catherine Dumas',
#  ' Daniel LaManna',
#  ' Teresa M. Harrison',
#  ' S.S. Ravi',
#  ' Loni Hagen',
#  ' Christopher Kotfila',
#  ' Feng Chen',
#  ' Norman Meuschke1',
#  '2',
#  ' Bela Gipp1',
#  ' Mario Lipinsk1',
#  ' Henry A. Gabb',
#  ' Ana Lucic',
#  ' Catherine Blake',
#  ' Toine Bogers1',
#  ' Vivien Petras2',
#  ' Adam Worrall',
#  ' Colin Doty',
#  ' Saleem Alhabash1',
#  '2',
#  ' Brandon Allen Brooks2',
#  ' Mengtian Jiang1',
#  ' Nora J Rifon1',
#  ' LaRose Robert2',
#  ' Cotten Shelia2',
#  ' Alissa Lorraine Centivany',
#  ' Alon Peled1',
#  ' Karine Nahon2',
#  '3',
#  ' Katie Shilton',
#  ' Michael Marcinkowski',
#  ' Frederico Fonseca',
#  ' Rob Grace',
#  ' Frederico Fonseca',
#  ' Tuan Cong Dang',
#  ' Jonathan Foster',
#  ' Williams Ezinwa Nwagwu',
#  ' Thomas Ludwig1',
#  ' Oliver Stickel1',
#  ' Alexander Boden2',
#  ' Volkmar Pipek1',
#  ' Volker Wulf1',
#  ' Hamid R. Ekbia1',
#  ' Bonnie Nardi2',
#  ' Selma Sabanovic1',
#  ' Donna Vakharia1',
#  ' Matthew Lease2',
#  ' Peter Organisciak',
#  ' Michael Twidale',
#  ' Elliot Tan1',
#  ' Huichuan Xia2',
#  ' Cheng Ji2',
#  ' Ritu Virendra Joshi2',
#  ' Yun Huang2',
#  ' Martin Shelton',
#  ' Katherine Lo',
#  ' Bonnie Nardi',
#  ' Munmun De Choudhury1',
#  ' Michael Massimi2',
#  ' Jinyoung Kim',
#  ' Myeong Lee',
#  ' Chiyoung Oh',
#  ' Karin Dessne',
#  ' Allyson Carlyle',
#  ' Susan Gasson',
#  ' Judit Bar-Ilan',
#  ' Jenny Bronstein',
#  ' Noa Aharony',
#  ' James Cheng1',
#  ' Monisha Manoharan2',
#  ' Yan Zhang1',
#  ' Matthew Lease1',
#  ' Donghee Yvette Wohn',
#  ' Patrick C. Shih',
#  ' Kyungsik Han',
#  ' Erika Shehan Poole',
#  ' Mary Beth Rosson',
#  ' John M. Carroll',
#  ' Elizabeth Eikey',
#  ' Erika Poole',
#  ' Madhu Reddy',
#  ' Shameem Ahmed1',
#  ' Moushumi Sharmin2',
#  ' Vanessa Kitzie',
#  ' R. J. Shillair',
#  ' R.V. Rikard',
#  ' S.R. Cotten',
#  ' H.Y. Tsai',
#  ' Kuo-Ting Huang',
#  ' Shelia Cotten',
#  ' Christopher Ball',
#  ' Anders Hjalmarsson1',
#  '2',
#  ' Eva Gustafsson1',
#  ' Stefan Cronholm1',
#  ' Daniel Carter',
#  ' Patrick Carrington2',
#  ' Shannon Hosmer2',
#  ' Tom Yeh1',
#  ' Amy Hurst2',
#  ' Shaun K. Kane1',
#  ' Roberto I Gonzalez-IbaÃ±ez1',
#  ' Chirag Shah2',
#  ' SoHyun Park',
#  ' Hyunchul Lim',
#  ' Heekyung Choi',
#  ' Chirag Shah',
#  ' Jennifer Sonne',
#  ' You Zheng',
#  ' Jason Dedrick',
#  ' Jess Kropczynski',
#  ' Cheryl Annette Thompson1',
#  ' Matthew S. Mayernik2',
#  ' Carole L. Palmer3',
#  ' Suzie Allard4',
#  ' Carol Tenopir4',
#  ' Michael Majewski Widdersheim',
#  ' Masanori Koizumi',
#  ' Siyuan Guo',
#  ' Trevor Edelblute',
#  ' Bin Dai',
#  ' Miao Chen',
#  ' Xiaozhong Liu',
#  '']

# %%
cleaned_authors = [] # for storing the cleaned authornames

for author in author_string.split(',')[:-1]: # skip last element
    if author[-1].isdigit(): # is the last char is a digit
        if author[:-1]: # is the entry only a digit
            cleaned_authors.append(author[:-1]) # save the clean author
    else: # this author doesn't need cleaning
        cleaned_authors.append(author) 
        
cleaned_authors
# Out:
# [' Steve Slota',
#  ' Geoffrey C. Bowker',
#  ' Drew Paine',
#  ' Erin Sy',
#  ' Ron Piell',
#  ' Charlotte P. Lee',
#  ' Peter T. Darch',
#  ' Ashley E. Sands',
#  ' Agnes Mainka',
#  ' Sarah Hartmann',
#  ' Christine Meschede',
#  ' Wolfgang G. Stock',
#  ' Catherine Dumas',
#  ' Daniel LaManna',
#  ' Teresa M. Harrison',
#  ' S.S. Ravi',
#  ' Loni Hagen',
#  ' Christopher Kotfila',
#  ' Feng Chen',
#  ' Norman Meuschke',
#  ' Bela Gipp',
#  ' Mario Lipinsk',
#  ' Henry A. Gabb',
#  ' Ana Lucic',
#  ' Catherine Blake',
#  ' Toine Bogers',
#  ' Vivien Petras',
#  ' Adam Worrall',
#  ' Colin Doty',
#  ' Saleem Alhabash',
#  ' Brandon Allen Brooks',
#  ' Mengtian Jiang',
#  ' Nora J Rifon',
#  ' LaRose Robert',
#  ' Cotten Shelia',
#  ' Alissa Lorraine Centivany',
#  ' Alon Peled',
#  ' Karine Nahon',
#  ' Katie Shilton',
#  ' Michael Marcinkowski',
#  ' Frederico Fonseca',
#  ' Rob Grace',
#  ' Frederico Fonseca',
#  ' Tuan Cong Dang',
#  ' Jonathan Foster',
#  ' Williams Ezinwa Nwagwu',
#  ' Thomas Ludwig',
#  ' Oliver Stickel',
#  ' Alexander Boden',
#  ' Volkmar Pipek',
#  ' Volker Wulf',
#  ' Hamid R. Ekbia',
#  ' Bonnie Nardi',
#  ' Selma Sabanovic',
#  ' Donna Vakharia',
#  ' Matthew Lease',
#  ' Peter Organisciak',
#  ' Michael Twidale',
#  ' Elliot Tan',
#  ' Huichuan Xia',
#  ' Cheng Ji',
#  ' Ritu Virendra Joshi',
#  ' Yun Huang',
#  ' Martin Shelton',
#  ' Katherine Lo',
#  ' Bonnie Nardi',
#  ' Munmun De Choudhury',
#  ' Michael Massimi',
#  ' Jinyoung Kim',
#  ' Myeong Lee',
#  ' Chiyoung Oh',
#  ' Karin Dessne',
#  ' Allyson Carlyle',
#  ' Susan Gasson',
#  ' Judit Bar-Ilan',
#  ' Jenny Bronstein',
#  ' Noa Aharony',
#  ' James Cheng',
#  ' Monisha Manoharan',
#  ' Yan Zhang',
#  ' Matthew Lease',
#  ' Donghee Yvette Wohn',
#  ' Patrick C. Shih',
#  ' Kyungsik Han',
#  ' Erika Shehan Poole',
#  ' Mary Beth Rosson',
#  ' John M. Carroll',
#  ' Elizabeth Eikey',
#  ' Erika Poole',
#  ' Madhu Reddy',
#  ' Shameem Ahmed',
#  ' Moushumi Sharmin',
#  ' Vanessa Kitzie',
#  ' R. J. Shillair',
#  ' R.V. Rikard',
#  ' S.R. Cotten',
#  ' H.Y. Tsai',
#  ' Kuo-Ting Huang',
#  ' Shelia Cotten',
#  ' Christopher Ball',
#  ' Anders Hjalmarsson',
#  ' Eva Gustafsson',
#  ' Stefan Cronholm',
#  ' Daniel Carter',
#  ' Patrick Carrington',
#  ' Shannon Hosmer',
#  ' Tom Yeh',
#  ' Amy Hurst',
#  ' Shaun K. Kane',
#  ' Roberto I Gonzalez-IbaÃ±ez',
#  ' Chirag Shah',
#  ' SoHyun Park',
#  ' Hyunchul Lim',
#  ' Heekyung Choi',
#  ' Chirag Shah',
#  ' Jennifer Sonne',
#  ' You Zheng',
#  ' Jason Dedrick',
#  ' Jess Kropczynski',
#  ' Cheryl Annette Thompson',
#  ' Matthew S. Mayernik',
#  ' Carole L. Palmer',
#  ' Suzie Allard',
#  ' Carol Tenopir',
#  ' Michael Majewski Widdersheim',
#  ' Masanori Koizumi',
#  ' Siyuan Guo',
#  ' Trevor Edelblute',
#  ' Bin Dai',
#  ' Miao Chen',
#  ' Xiaozhong Liu']

# %%
# ok we hae a nice list, now let's see if we can sort by last name
authors_lastname = []

for author in cleaned_authors:
    split_author = author.split(' ')
    author_lastname = ",".join([split_author[-1]," ".join(split_author[:-1])])
    authors_lastname.append(author_lastname)

authors_lastname
# Out:
# ['Slota, Steve',
#  'Bowker, Geoffrey C.',
#  'Paine, Drew',
#  'Sy, Erin',
#  'Piell, Ron',
#  'Lee, Charlotte P.',
#  'Darch, Peter T.',
#  'Sands, Ashley E.',
#  'Mainka, Agnes',
#  'Hartmann, Sarah',
#  'Meschede, Christine',
#  'Stock, Wolfgang G.',
#  'Dumas, Catherine',
#  'LaManna, Daniel',
#  'Harrison, Teresa M.',
#  'Ravi, S.S.',
#  'Hagen, Loni',
#  'Kotfila, Christopher',
#  'Chen, Feng',
#  'Meuschke, Norman',
#  'Gipp, Bela',
#  'Lipinsk, Mario',
#  'Gabb, Henry A.',
#  'Lucic, Ana',
#  'Blake, Catherine',
#  'Bogers, Toine',
#  'Petras, Vivien',
#  'Worrall, Adam',
#  'Doty, Colin',
#  'Alhabash, Saleem',
#  'Brooks, Brandon Allen',
#  'Jiang, Mengtian',
#  'Rifon, Nora J',
#  'Robert, LaRose',
#  'Shelia, Cotten',
#  'Centivany, Alissa Lorraine',
#  'Peled, Alon',
#  'Nahon, Karine',
#  'Shilton, Katie',
#  'Marcinkowski, Michael',
#  'Fonseca, Frederico',
#  'Grace, Rob',
#  'Fonseca, Frederico',
#  'Dang, Tuan Cong',
#  'Foster, Jonathan',
#  'Nwagwu, Williams Ezinwa',
#  'Ludwig, Thomas',
#  'Stickel, Oliver',
#  'Boden, Alexander',
#  'Pipek, Volkmar',
#  'Wulf, Volker',
#  'Ekbia, Hamid R.',
#  'Nardi, Bonnie',
#  'Sabanovic, Selma',
#  'Vakharia, Donna',
#  'Lease, Matthew',
#  'Organisciak, Peter',
#  'Twidale, Michael',
#  'Tan, Elliot',
#  'Xia, Huichuan',
#  'Ji, Cheng',
#  'Joshi, Ritu Virendra',
#  'Huang, Yun',
#  'Shelton, Martin',
#  'Lo, Katherine',
#  'Nardi, Bonnie',
#  'Choudhury, Munmun De',
#  'Massimi, Michael',
#  'Kim, Jinyoung',
#  'Lee, Myeong',
#  'Oh, Chiyoung',
#  'Dessne, Karin',
#  'Carlyle, Allyson',
#  'Gasson, Susan',
#  'Bar-Ilan, Judit',
#  'Bronstein, Jenny',
#  'Aharony, Noa',
#  'Cheng, James',
#  'Manoharan, Monisha',
#  'Zhang, Yan',
#  'Lease, Matthew',
#  'Wohn, Donghee Yvette',
#  'Shih, Patrick C.',
#  'Han, Kyungsik',
#  'Poole, Erika Shehan',
#  'Rosson, Mary Beth',
#  'Carroll, John M.',
#  'Eikey, Elizabeth',
#  'Poole, Erika',
#  'Reddy, Madhu',
#  'Ahmed, Shameem',
#  'Sharmin, Moushumi',
#  'Kitzie, Vanessa',
#  'Shillair, R. J.',
#  'Rikard, R.V.',
#  'Cotten, S.R.',
#  'Tsai, H.Y.',
#  'Huang, Kuo-Ting',
#  'Cotten, Shelia',
#  'Ball, Christopher',
#  'Hjalmarsson, Anders',
#  'Gustafsson, Eva',
#  'Cronholm, Stefan',
#  'Carter, Daniel',
#  'Carrington, Patrick',
#  'Hosmer, Shannon',
#  'Yeh, Tom',
#  'Hurst, Amy',
#  'Kane, Shaun K.',
#  'Gonzalez-IbaÃ±ez, Roberto I',
#  'Shah, Chirag',
#  'Park, SoHyun',
#  'Lim, Hyunchul',
#  'Choi, Heekyung',
#  'Shah, Chirag',
#  'Sonne, Jennifer',
#  'Zheng, You',
#  'Dedrick, Jason',
#  'Kropczynski, Jess',
#  'Thompson, Cheryl Annette',
#  'Mayernik, Matthew S.',
#  'Palmer, Carole L.',
#  'Allard, Suzie',
#  'Tenopir, Carol',
#  'Widdersheim, Michael Majewski',
#  'Koizumi, Masanori',
#  'Guo, Siyuan',
#  'Edelblute, Trevor',
#  'Dai, Bin',
#  'Chen, Miao',
#  'Liu, Xiaozhong']

# %%
sorted(authors_lastname)
# Out:
# ['Aharony, Noa',
#  'Ahmed, Shameem',
#  'Alhabash, Saleem',
#  'Allard, Suzie',
#  'Ball, Christopher',
#  'Bar-Ilan, Judit',
#  'Blake, Catherine',
#  'Boden, Alexander',
#  'Bogers, Toine',
#  'Bowker, Geoffrey C.',
#  'Bronstein, Jenny',
#  'Brooks, Brandon Allen',
#  'Carlyle, Allyson',
#  'Carrington, Patrick',
#  'Carroll, John M.',
#  'Carter, Daniel',
#  'Centivany, Alissa Lorraine',
#  'Chen, Feng',
#  'Chen, Miao',
#  'Cheng, James',
#  'Choi, Heekyung',
#  'Choudhury, Munmun De',
#  'Cotten, S.R.',
#  'Cotten, Shelia',
#  'Cronholm, Stefan',
#  'Dai, Bin',
#  'Dang, Tuan Cong',
#  'Darch, Peter T.',
#  'Dedrick, Jason',
#  'Dessne, Karin',
#  'Doty, Colin',
#  'Dumas, Catherine',
#  'Edelblute, Trevor',
#  'Eikey, Elizabeth',
#  'Ekbia, Hamid R.',
#  'Fonseca, Frederico',
#  'Fonseca, Frederico',
#  'Foster, Jonathan',
#  'Gabb, Henry A.',
#  'Gasson, Susan',
#  'Gipp, Bela',
#  'Gonzalez-IbaÃ±ez, Roberto I',
#  'Grace, Rob',
#  'Guo, Siyuan',
#  'Gustafsson, Eva',
#  'Hagen, Loni',
#  'Han, Kyungsik',
#  'Harrison, Teresa M.',
#  'Hartmann, Sarah',
#  'Hjalmarsson, Anders',
#  'Hosmer, Shannon',
#  'Huang, Kuo-Ting',
#  'Huang, Yun',
#  'Hurst, Amy',
#  'Ji, Cheng',
#  'Jiang, Mengtian',
#  'Joshi, Ritu Virendra',
#  'Kane, Shaun K.',
#  'Kim, Jinyoung',
#  'Kitzie, Vanessa',
#  'Koizumi, Masanori',
#  'Kotfila, Christopher',
#  'Kropczynski, Jess',
#  'LaManna, Daniel',
#  'Lease, Matthew',
#  'Lease, Matthew',
#  'Lee, Charlotte P.',
#  'Lee, Myeong',
#  'Lim, Hyunchul',
#  'Lipinsk, Mario',
#  'Liu, Xiaozhong',
#  'Lo, Katherine',
#  'Lucic, Ana',
#  'Ludwig, Thomas',
#  'Mainka, Agnes',
#  'Manoharan, Monisha',
#  'Marcinkowski, Michael',
#  'Massimi, Michael',
#  'Mayernik, Matthew S.',
#  'Meschede, Christine',
#  'Meuschke, Norman',
#  'Nahon, Karine',
#  'Nardi, Bonnie',
#  'Nardi, Bonnie',
#  'Nwagwu, Williams Ezinwa',
#  'Oh, Chiyoung',
#  'Organisciak, Peter',
#  'Paine, Drew',
#  'Palmer, Carole L.',
#  'Park, SoHyun',
#  'Peled, Alon',
#  'Petras, Vivien',
#  'Piell, Ron',
#  'Pipek, Volkmar',
#  'Poole, Erika',
#  'Poole, Erika Shehan',
#  'Ravi, S.S.',
#  'Reddy, Madhu',
#  'Rifon, Nora J',
#  'Rikard, R.V.',
#  'Robert, LaRose',
#  'Rosson, Mary Beth',
#  'Sabanovic, Selma',
#  'Sands, Ashley E.',
#  'Shah, Chirag',
#  'Shah, Chirag',
#  'Sharmin, Moushumi',
#  'Shelia, Cotten',
#  'Shelton, Martin',
#  'Shih, Patrick C.',
#  'Shillair, R. J.',
#  'Shilton, Katie',
#  'Slota, Steve',
#  'Sonne, Jennifer',
#  'Stickel, Oliver',
#  'Stock, Wolfgang G.',
#  'Sy, Erin',
#  'Tan, Elliot',
#  'Tenopir, Carol',
#  'Thompson, Cheryl Annette',
#  'Tsai, H.Y.',
#  'Twidale, Michael',
#  'Vakharia, Donna',
#  'Widdersheim, Michael Majewski',
#  'Wohn, Donghee Yvette',
#  'Worrall, Adam',
#  'Wulf, Volker',
#  'Xia, Huichuan',
#  'Yeh, Tom',
#  'Zhang, Yan',
#  'Zheng, You']

# %%
# remove the duplicate authors with set operations and print out a nice list
print("There are", len(set(authors_lastname)), "authors of completed papers.\n")
for author in sorted(set(authors_lastname)):
    print(author)
# Out:
# There are 127 authors of completed papers.
#
# Aharony, Noa
# Ahmed, Shameem
# Alhabash, Saleem
# Allard, Suzie
# Ball, Christopher
# Bar-Ilan, Judit
# Blake, Catherine
# Boden, Alexander
# Bogers, Toine
# Bowker, Geoffrey C.
# Bronstein, Jenny
# Brooks, Brandon Allen
# Carlyle, Allyson
# Carrington, Patrick
# Carroll, John M.
# Carter, Daniel
# Centivany, Alissa Lorraine
# Chen, Feng
# Chen, Miao
# Cheng, James
# Choi, Heekyung
# Choudhury, Munmun De
# Cotten, S.R.
# Cotten, Shelia
# Cronholm, Stefan
# Dai, Bin
# Dang, Tuan Cong
# Darch, Peter T.
# Dedrick, Jason
# Dessne, Karin
# Doty, Colin
# Dumas, Catherine
# Edelblute, Trevor
# Eikey, Elizabeth
# Ekbia, Hamid R.
# Fonseca, Frederico
# Foster, Jonathan
# Gabb, Henry A.
# Gasson, Susan
# Gipp, Bela
# Gonzalez-IbaÃ±ez, Roberto I
# Grace, Rob
# Guo, Siyuan
# Gustafsson, Eva
# Hagen, Loni
# Han, Kyungsik
# Harrison, Teresa M.
# Hartmann, Sarah
# Hjalmarsson, Anders
# Hosmer, Shannon
# Huang, Kuo-Ting
# Huang, Yun
# Hurst, Amy
# Ji, Cheng
# Jiang, Mengtian
# Joshi, Ritu Virendra
# Kane, Shaun K.
# Kim, Jinyoung
# Kitzie, Vanessa
# Koizumi, Masanori
# Kotfila, Christopher
# Kropczynski, Jess
# LaManna, Daniel
# Lease, Matthew
# Lee, Charlotte P.
# Lee, Myeong
# Lim, Hyunchul
# Lipinsk, Mario
# Liu, Xiaozhong
# Lo, Katherine
# Lucic, Ana
# Ludwig, Thomas
# Mainka, Agnes
# Manoharan, Monisha
# Marcinkowski, Michael
# Massimi, Michael
# Mayernik, Matthew S.
# Meschede, Christine
# Meuschke, Norman
# Nahon, Karine
# Nardi, Bonnie
# Nwagwu, Williams Ezinwa
# Oh, Chiyoung
# Organisciak, Peter
# Paine, Drew
# Palmer, Carole L.
# Park, SoHyun
# Peled, Alon
# Petras, Vivien
# Piell, Ron
# Pipek, Volkmar
# Poole, Erika
# Poole, Erika Shehan
# Ravi, S.S.
# Reddy, Madhu
# Rifon, Nora J
# Rikard, R.V.
# Robert, LaRose
# Rosson, Mary Beth
# Sabanovic, Selma
# Sands, Ashley E.
# Shah, Chirag
# Sharmin, Moushumi
# Shelia, Cotten
# Shelton, Martin
# Shih, Patrick C.
# Shillair, R. J.
# Shilton, Katie
# Slota, Steve
# Sonne, Jennifer
# Stickel, Oliver
# Stock, Wolfgang G.
# Sy, Erin
# Tan, Elliot
# Tenopir, Carol
# Thompson, Cheryl Annette
# Tsai, H.Y.
# Twidale, Michael
# Vakharia, Donna
# Widdersheim, Michael Majewski
# Wohn, Donghee Yvette
# Worrall, Adam
# Wulf, Volker
# Xia, Huichuan
# Yeh, Tom
# Zhang, Yan
# Zheng, You
